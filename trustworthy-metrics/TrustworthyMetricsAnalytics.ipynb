# %%
import pandas as pd
import numpy as np
import pathlib
import json
import matplotlib.pyplot as plt
import requests
import pathlib

# %% [markdown]
# # If running locally, download the latest metrics from the IC Mainnet

# %%
# !test -f ~/.config/dfx/identity/ic-fa3em/identity.pem && \
  dre --private-key-pem ~/.config/dfx/identity/ic-fa3em/identity.pem trustworthy-metrics nanx4-baaaa-aaaap-qb4sq-cai 0 > data.json
# Out:
#  INFO  dre > Running version 0.2.1-d1fe2c7
#  INFO  ic_management_backend::registry > Using local registry path for network mainnet: /home/sat/.cache/ic-registry-cache/mainnet/local_registry
#  INFO  ic_management_backend::git_ic_repo > IC git repo path: /home/sat/.cache/git/ic, lock file path: /home/sat/.cache/git/ic.lock
#  INFO  ic_management_backend::registry    > Found 6 branches for git rev: a7862784e8da4a97a1d608fd5b3db365de41a2d7
#  INFO  ic_management_backend::registry    > Found 9 branches for git rev: fed4316368b93245120ceb0596423c715bb31ff0
#  WARN  ic_management_backend::registry    > branch fed4316368b93245120ceb0596423c715bb31ff0 for git rev gary/bare-metal-ci-job does not match RC regex
#  INFO  ic_management_backend::registry    > Found 1 branches for git rev: 072b2a6586c409efa88f2244d658307ff3a645d8
#  INFO  ic_management_backend::registry    > Found 40 branches for git rev: ec140b74dc4fef2f4bee3fad936e315380fa5af3
#  WARN  ic_management_backend::registry    > branch ec140b74dc4fef2f4bee3fad936e315380fa5af3 for git rev hotfix-no-rc--nns-2023-11-20 does not match RC regex
#  INFO  ic_management_backend::registry    > Found 1 branches for git rev: 044cfd5147fc97d7e5a214966941b6580c325d72
#  INFO  ic_management_backend::registry    > Found 1 branches for git rev: 324eb99eb7531369a5ef75560f1a1a652d123714
#  INFO  ic_management_backend::registry    > Found 7 branches for git rev: 5c60feaf3d64a745b9a44aa61d44b91d6921541b
#  INFO  ic_management_backend::registry    > Found 1 branches for git rev: 84bfbf8be2e2949c012ed5cf7e66c8da5461ecd2
#  INFO  ic_management_backend::registry    > Found 47 branches for git rev: e268b9807f1ab4ae65d7b29fe70a3b358d014d6a
#  WARN  ic_management_backend::registry    > branch e268b9807f1ab4ae65d7b29fe70a3b358d014d6a for git rev hotfix-no-rc--nns-2023-11-20 does not match RC regex
#  INFO  ic_management_backend::endpoints   > Backend started at 127.0.0.1:38371
#  INFO  dre::ic_admin                      > Using ic-admin: /home/sat/bin/ic-admin.revisions/e7c7105a54fdf43892c46b5560d5dbee687dcba0/ic-admin
#  INFO  dre::general                       > Started action...
#  INFO  dre::general                       > Running in parallel mode
#  INFO  dre::general                       > Spawning thread for subnet: tdb26-jop6k-aogll-7ltgs-eruif-6kk7m-qpktf-gdiqx-mxtrf-vb5e6-eqe
#  INFO  dre::general                       > Spawning thread for subnet: snjp4-xlbw4-mnbog-ddwy6-6ckfd-2w5a2-eipqo-7l436-pxqkh-l6fuv-vae
#  INFO  dre::general                       > Spawning thread for subnet: qxesv-zoxpm-vc64m-zxguk-5sj74-35vrb-tbgwg-pcird-5gr26-62oxl-cae
#  INFO  dre::general                       > Spawning thread for subnet: pae4o-o6dxf-xki7q-ezclx-znyd6-fnk6w-vkv5z-5lfwh-xym2i-otrrw-fqe
#  INFO  dre::general                       > Spawning thread for subnet: 4zbus-z2bmt-ilreg-xakz4-6tyre-hsqj4-slb4g-zjwqo-snjcc-iqphi-3qe
#  INFO  dre::general                       > Spawning thread for subnet: w4asl-4nmyj-qnr7c-6cqq4-tkwmt-o26di-iupkq-vx4kt-asbrx-jzuxh-4ae
#  INFO  dre::general                       > Spawning thread for subnet: io67a-2jmkw-zup3h-snbwi-g6a5n-rm5dn-b6png-lvdpl-nqnto-yih6l-gqe
#  INFO  dre::general                       > Spawning thread for subnet: 5kdm2-62fc6-fwnja-hutkz-ycsnm-4z33i-woh43-4cenu-ev7mi-gii6t-4ae
#  INFO  dre::general                       > Spawning thread for subnet: shefu-t3kr5-t5q3w-mqmdq-jabyv-vyvtf-cyyey-3kmo4-toyln-emubw-4qe
#  INFO  dre::general                       > Spawning thread for subnet: ejbmu-grnam-gk6ol-6irwa-htwoj-7ihfl-goimw-hlnvh-abms4-47v2e-zqe
#  INFO  dre::general                       > Spawning thread for subnet: eq6en-6jqla-fbu5s-daskr-h6hx2-376n5-iqabl-qgrng-gfqmv-n3yjr-mqe
#  INFO  dre::general                       > Spawning thread for subnet: csyj4-zmann-ys6ge-3kzi6-onexi-obayx-2fvak-zersm-euci4-6pslt-lae
#  INFO  dre::general                       > Spawning thread for subnet: lspz2-jx4pu-k3e7p-znm7j-q4yum-ork6e-6w4q6-pijwq-znehu-4jabe-kqe
#  INFO  dre::general                       > Spawning thread for subnet: lhg73-sax6z-2zank-6oer2-575lz-zgbxx-ptudx-5korm-fy7we-kh4hl-pqe
#  INFO  dre::general                       > Spawning thread for subnet: gmq5v-hbozq-uui6y-o55wc-ihop3-562wb-3qspg-nnijg-npqp5-he3cj-3ae
#  INFO  dre::general                       > Spawning thread for subnet: pjljw-kztyl-46ud4-ofrj6-nzkhm-3n4nt-wi3jt-ypmav-ijqkt-gjf66-uae
#  INFO  dre::general                       > Spawning thread for subnet: brlsh-zidhj-3yy3e-6vqbz-7xnih-xeq2l-as5oc-g32c4-i5pdn-2wwof-oae
#  INFO  dre::general                       > Spawning thread for subnet: mpubz-g52jc-grhjo-5oze5-qcj74-sex34-omprz-ivnsm-qvvhr-rfzpv-vae
#  INFO  dre::general                       > Spawning thread for subnet: qdvhd-os4o2-zzrdw-xrcv4-gljou-eztdp-bj326-e6jgr-tkhuc-ql6v2-yqe
#  INFO  dre::general                       > Spawning thread for subnet: jtdsg-3h6gi-hs7o5-z2soi-43w3z-soyl3-ajnp3-ekni5-sw553-5kw67-nqe
#  INFO  dre::general                       > Spawning thread for subnet: k44fs-gm4pv-afozh-rs7zw-cg32n-u7xov-xqyx3-2pw5q-eucnu-cosd4-uqe
#  INFO  dre::general                       > Spawning thread for subnet: opn46-zyspe-hhmyp-4zu6u-7sbrh-dok77-m7dch-im62f-vyimr-a3n2c-4ae
#  INFO  dre::general                       > Spawning thread for subnet: 6pbhf-qzpdk-kuqbr-pklfa-5ehhf-jfjps-zsj6q-57nrl-kzhpd-mu7hc-vae
#  INFO  dre::general                       > Spawning thread for subnet: e66qm-3cydn-nkf4i-ml4rb-4ro6o-srm5s-x5hwq-hnprz-3meqp-s7vks-5qe
#  INFO  dre::general                       > Spawning thread for subnet: 4ecnw-byqwz-dtgss-ua2mh-pfvs7-c3lct-gtf4e-hnu75-j7eek-iifqm-sqe
#  INFO  dre::general                       > Spawning thread for subnet: yinp6-35cfo-wgcd2-oc4ty-2kqpf-t4dul-rfk33-fsq3r-mfmua-m2ngh-jqe
#  INFO  dre::general                       > Spawning thread for subnet: w4rem-dv5e3-widiz-wbpea-kbttk-mnzfm-tzrc7-svcj3-kbxyb-zamch-hqe
#  INFO  dre::general                       > Spawning thread for subnet: cv73p-6v7zi-u67oy-7jc3h-qspsz-g5lrj-4fn7k-xrax3-thek2-sl46v-jae
#  INFO  dre::general                       > Spawning thread for subnet: o3ow2-2ipam-6fcjo-3j5vt-fzbge-2g7my-5fz2m-p4o2t-dwlc4-gt2q7-5ae
#  INFO  dre::general                       > Spawning thread for subnet: fuqsr-in2lc-zbcjj-ydmcw-pzq7h-4xm2z-pto4i-dcyee-5z4rz-x63ji-nae
#  INFO  dre::general                       > Spawning thread for subnet: 3hhby-wmtmw-umt4t-7ieyg-bbiig-xiylg-sblrt-voxgt-bqckd-a75bf-rqe
#  INFO  dre::general                       > Spawning thread for subnet: nl6hn-ja4yw-wvmpy-3z2jx-ymc34-pisx3-3cp5z-3oj4a-qzzny-jbsv3-4qe
#  INFO  dre::general                       > Spawning thread for subnet: x33ed-h457x-bsgyx-oqxqf-6pzwv-wkhzr-rm2j3-npodi-purzm-n66cg-gae
#  INFO  dre::general                       > Spawning thread for subnet: uzr34-akd3s-xrdag-3ql62-ocgoh-ld2ao-tamcv-54e7j-krwgb-2gm4z-oqe
#  INFO  dre::general                       > Spawning thread for subnet: 2fq7c-slacv-26cgz-vzbx2-2jrcs-5edph-i5s2j-tck77-c3rlz-iobzx-mqe
#  INFO  dre::general                       > Spawning thread for subnet: pzp6e-ekpqk-3c5x7-2h6so-njoeq-mt45d-h3h6c-q3mxf-vpeq5-fk5o7-yae
#  INFO  dre::general                       > Spawning thread for subnet: bkfrj-6k62g-dycql-7h53p-atvkj-zg4to-gaogh-netha-ptybj-ntsgw-rqe
#  INFO  dre::general                       > Received response for subnet: tdb26-jop6k-aogll-7ltgs-eruif-6kk7m-qpktf-gdiqx-mxtrf-vb5e6-eqe
#  INFO  dre::general                       > Received response for subnet: snjp4-xlbw4-mnbog-ddwy6-6ckfd-2w5a2-eipqo-7l436-pxqkh-l6fuv-vae
#  INFO  dre::general                       > Received response for subnet: qxesv-zoxpm-vc64m-zxguk-5sj74-35vrb-tbgwg-pcird-5gr26-62oxl-cae
#  INFO  dre::general                       > Received response for subnet: pae4o-o6dxf-xki7q-ezclx-znyd6-fnk6w-vkv5z-5lfwh-xym2i-otrrw-fqe
#  INFO  dre::general                       > Received response for subnet: 4zbus-z2bmt-ilreg-xakz4-6tyre-hsqj4-slb4g-zjwqo-snjcc-iqphi-3qe
#  INFO  dre::general                       > Received response for subnet: w4asl-4nmyj-qnr7c-6cqq4-tkwmt-o26di-iupkq-vx4kt-asbrx-jzuxh-4ae
#  INFO  dre::general                       > Received response for subnet: io67a-2jmkw-zup3h-snbwi-g6a5n-rm5dn-b6png-lvdpl-nqnto-yih6l-gqe
#  INFO  dre::general                       > Received response for subnet: 5kdm2-62fc6-fwnja-hutkz-ycsnm-4z33i-woh43-4cenu-ev7mi-gii6t-4ae
#  INFO  dre::general                       > Received response for subnet: shefu-t3kr5-t5q3w-mqmdq-jabyv-vyvtf-cyyey-3kmo4-toyln-emubw-4qe
#  INFO  dre::general                       > Received response for subnet: ejbmu-grnam-gk6ol-6irwa-htwoj-7ihfl-goimw-hlnvh-abms4-47v2e-zqe
#  INFO  dre::general                       > Received response for subnet: eq6en-6jqla-fbu5s-daskr-h6hx2-376n5-iqabl-qgrng-gfqmv-n3yjr-mqe
#  INFO  dre::general                       > Received response for subnet: csyj4-zmann-ys6ge-3kzi6-onexi-obayx-2fvak-zersm-euci4-6pslt-lae
#  INFO  dre::general                       > Received response for subnet: lspz2-jx4pu-k3e7p-znm7j-q4yum-ork6e-6w4q6-pijwq-znehu-4jabe-kqe
#  INFO  dre::general                       > Received response for subnet: lhg73-sax6z-2zank-6oer2-575lz-zgbxx-ptudx-5korm-fy7we-kh4hl-pqe
#  INFO  dre::general                       > Received response for subnet: gmq5v-hbozq-uui6y-o55wc-ihop3-562wb-3qspg-nnijg-npqp5-he3cj-3ae
#  INFO  dre::general                       > Received response for subnet: pjljw-kztyl-46ud4-ofrj6-nzkhm-3n4nt-wi3jt-ypmav-ijqkt-gjf66-uae
#  INFO  dre::general                       > Received response for subnet: brlsh-zidhj-3yy3e-6vqbz-7xnih-xeq2l-as5oc-g32c4-i5pdn-2wwof-oae
#  INFO  dre::general                       > Received response for subnet: mpubz-g52jc-grhjo-5oze5-qcj74-sex34-omprz-ivnsm-qvvhr-rfzpv-vae
#  INFO  dre::general                       > Received response for subnet: qdvhd-os4o2-zzrdw-xrcv4-gljou-eztdp-bj326-e6jgr-tkhuc-ql6v2-yqe
#  INFO  dre::general                       > Received response for subnet: jtdsg-3h6gi-hs7o5-z2soi-43w3z-soyl3-ajnp3-ekni5-sw553-5kw67-nqe
#  INFO  dre::general                       > Received response for subnet: k44fs-gm4pv-afozh-rs7zw-cg32n-u7xov-xqyx3-2pw5q-eucnu-cosd4-uqe
#  INFO  dre::general                       > Received response for subnet: opn46-zyspe-hhmyp-4zu6u-7sbrh-dok77-m7dch-im62f-vyimr-a3n2c-4ae
#  INFO  dre::general                       > Received response for subnet: 6pbhf-qzpdk-kuqbr-pklfa-5ehhf-jfjps-zsj6q-57nrl-kzhpd-mu7hc-vae
#  INFO  dre::general                       > Received response for subnet: e66qm-3cydn-nkf4i-ml4rb-4ro6o-srm5s-x5hwq-hnprz-3meqp-s7vks-5qe
#  INFO  dre::general                       > Received response for subnet: 4ecnw-byqwz-dtgss-ua2mh-pfvs7-c3lct-gtf4e-hnu75-j7eek-iifqm-sqe
#  INFO  dre::general                       > Received response for subnet: yinp6-35cfo-wgcd2-oc4ty-2kqpf-t4dul-rfk33-fsq3r-mfmua-m2ngh-jqe
#  INFO  dre::general                       > Received response for subnet: w4rem-dv5e3-widiz-wbpea-kbttk-mnzfm-tzrc7-svcj3-kbxyb-zamch-hqe
#  INFO  dre::general                       > Received response for subnet: cv73p-6v7zi-u67oy-7jc3h-qspsz-g5lrj-4fn7k-xrax3-thek2-sl46v-jae
#  INFO  dre::general                       > Received response for subnet: o3ow2-2ipam-6fcjo-3j5vt-fzbge-2g7my-5fz2m-p4o2t-dwlc4-gt2q7-5ae
#  INFO  dre::general                       > Received response for subnet: fuqsr-in2lc-zbcjj-ydmcw-pzq7h-4xm2z-pto4i-dcyee-5z4rz-x63ji-nae
#  INFO  dre::general                       > Received response for subnet: 3hhby-wmtmw-umt4t-7ieyg-bbiig-xiylg-sblrt-voxgt-bqckd-a75bf-rqe
#  INFO  dre::general                       > Received response for subnet: nl6hn-ja4yw-wvmpy-3z2jx-ymc34-pisx3-3cp5z-3oj4a-qzzny-jbsv3-4qe
#  INFO  dre::general                       > Received response for subnet: x33ed-h457x-bsgyx-oqxqf-6pzwv-wkhzr-rm2j3-npodi-purzm-n66cg-gae
#  INFO  dre::general                       > Received response for subnet: uzr34-akd3s-xrdag-3ql62-ocgoh-ld2ao-tamcv-54e7j-krwgb-2gm4z-oqe
#  INFO  dre::general                       > Received response for subnet: 2fq7c-slacv-26cgz-vzbx2-2jrcs-5edph-i5s2j-tck77-c3rlz-iobzx-mqe
#  INFO  dre::general                       > Received response for subnet: pzp6e-ekpqk-3c5x7-2h6so-njoeq-mt45d-h3h6c-q3mxf-vpeq5-fk5o7-yae
#  INFO  dre::general                       > Received response for subnet: bkfrj-6k62g-dycql-7h53p-atvkj-zg4to-gaogh-netha-ptybj-ntsgw-rqe

# %% [markdown]
# # Load data

# %%
data_json = pathlib.Path("data.json")
if not data_json.exists():
    contents = requests.get("https://github.com/dfinity/dre/raw/main/docs/trustworthy-metrics/data.json").text
    data_json.write_text(contents)
data = json.load(pathlib.Path("data.json").open())
data_flat = []
for subnet_id, subnet_data in data.items():
    node_last_entry = {}
    for day in subnet_data:
        ts_nanos = day["timestamp_nanos"]
        day_data = day["node_metrics"]
        for entry in day_data:
            node_id = entry["node_id"]
            # Calculate diff (increase) from the entry with the previous timestamp
            prev_entry = node_last_entry.get(node_id, {})
            if entry["num_blocks_total"] == 0 or not prev_entry:
                entry["num_blocks_diff"] = 0
                entry["num_block_failures_diff"] = 0
            else:
                entry["num_blocks_diff"] = entry["num_blocks_total"] - prev_entry.get("num_blocks_total", 0)
                entry["num_block_failures_diff"] = entry["num_block_failures_total"] - prev_entry.get("num_block_failures_total", 0)
            node_last_entry[node_id] = entry
            entry["subnet_id"] = subnet_id
            entry["timestamp_nanos"] = ts_nanos
            data_flat.append(entry)
df = pd.json_normalize(data_flat)
df["date"] = pd.to_datetime(df["timestamp_nanos"]).dt.round("D")
df["node_failed_rounds_percent"] = (df["num_block_failures_diff"] * 100 / (df["num_blocks_diff"]+df["num_block_failures_diff"])).replace(np.inf, 0).fillna(0)

# %% [markdown]
# # How many days of metrics do we have?

# %%
len(df["date"].unique())
# Out:
# 59

# %% [markdown]
# # Show the DataFrame sorted by "node_failed_rounds_percent"

# %%
df.sort_values("node_failed_rounds_percent")
# Out:
#                                                  node_id  num_blocks_total  \
# 0      3ppfv-vqufk-yrg2j-nos4h-6fxos-iucst-jsf7h-be4f...             65378
# 20125  vhw72-z4xlu-g2ee2-7owc7-6qk6u-j6jhm-cfzk4-2jty...            470889
# 7083   4ifvf-q4djg-kzooi-5xvs6-66adz-6mysk-c2bz6-osui...             42233
# 20124  bayvy-p36kq-krz3d-o5lay-rxx3w-h35pc-235tv-mmhf...            471253
# 7085   5cphe-ynceg-ybsv7-5fpo7-rxte2-hbmm6-wkren-7lyf...             42082
# ...                                                  ...               ...
# 24841  ehizo-zv4le-hkzuy-gqyvw-6enab-mazoj-p57ci-kese...            221083
# 24834  yuhde-ypx4v-v7kmi-z3wye-fcd2n-ztakc-7ahvu-rn66...            170512
# 4965   r5i76-zvt2k-ssuo3-on5tn-gl7fr-vvx3g-mits2-inmh...            227984
# 24880  ehizo-zv4le-hkzuy-gqyvw-6enab-mazoj-p57ci-kese...            221083
# 24958  ehizo-zv4le-hkzuy-gqyvw-6enab-mazoj-p57ci-kese...            221083
#
#        num_block_failures_total  num_blocks_diff  num_block_failures_diff  \
# 0                          3089                0                        0
# 20125                       474             7940                        0
# 7083                        252             2267                        0
# 20124                       493             7892                        0
# 7085                        205             2276                        0
# ...                         ...              ...                      ...
# 24841                      9840                0                     5716
# 24834                     47653                0                     2640
# 4965                      64403                0                     6729
# 24880                     26954                0                     5653
# 24958                     61057                0                     5821
#
#                                                subnet_id      timestamp_nanos  \
# 0      3hhby-wmtmw-umt4t-7ieyg-bbiig-xiylg-sblrt-voxg...  1701561599308218775
# 20125  ejbmu-grnam-gk6ol-6irwa-htwoj-7ihfl-goimw-hlnv...  1706054399252105983
# 7083   uzr34-akd3s-xrdag-3ql62-ocgoh-ld2ao-tamcv-54e7...  1702166398758045667
# 20124  ejbmu-grnam-gk6ol-6irwa-htwoj-7ihfl-goimw-hlnv...  1706054399252105983
# 7085   uzr34-akd3s-xrdag-3ql62-ocgoh-ld2ao-tamcv-54e7...  1702166398758045667
# ...                                                  ...                  ...
# 24841  k44fs-gm4pv-afozh-rs7zw-cg32n-u7xov-xqyx3-2pw5...  1703548799615508191
# 24834  k44fs-gm4pv-afozh-rs7zw-cg32n-u7xov-xqyx3-2pw5...  1703462399261642142
# 4965   csyj4-zmann-ys6ge-3kzi6-onexi-obayx-2fvak-zers...  1704153599613121951
# 24880  k44fs-gm4pv-afozh-rs7zw-cg32n-u7xov-xqyx3-2pw5...  1703807999409662811
# 24958  k44fs-gm4pv-afozh-rs7zw-cg32n-u7xov-xqyx3-2pw5...  1704326399299891933
#
#             date  node_failed_rounds_percent
# 0     2023-12-03                         0.0
# 20125 2024-01-24                         0.0
# 7083  2023-12-10                         0.0
# 20124 2024-01-24                         0.0
# 7085  2023-12-10                         0.0
# ...          ...                         ...
# 24841 2023-12-26                       100.0
# 24834 2023-12-25                       100.0
# 4965  2024-01-02                       100.0
# 24880 2023-12-29                       100.0
# 24958 2024-01-04                       100.0
#
# [32988 rows x 9 columns]

# %% [markdown]
# # Count number of days per node, for which the node failed to be productive in 10% or more block rounds per day

# %%
df[df["node_failed_rounds_percent"] > 10].groupby("node_id").node_id.count().sort_values()
# Out:
# node_id
# dkx5h-i5d56-xeb37-uldi5-dlgmp-atrom-gyfn7-edeih-i5ph6-2cquy-dqe     1
# 7exbb-k4tu4-mw24y-3zylh-bopa5-fwdsc-f4a3z-45hh4-twpin-4zv4a-yae     1
# 6qxes-2iftw-fq3we-unkdt-y7wnk-4v26t-fftzu-chgeh-t2ljb-qtevx-iae     1
# nxeqo-y6jk3-5zpcu-waryv-lz3ha-c2iuu-jljee-yzew7-jo5dk-6dgr7-3qe     1
# 4vpak-qnqtn-vggke-um4f2-zkk2m-awc6p-bkhi5-cm22y-zhdiz-yx5rt-cqe     1
#                                                                    ..
# h7abv-ipt46-s3pz3-pzbaz-lw63i-7zgtk-u7hp2-gjcbq-orou3-nxrjy-lae    16
# xgqku-jngij-orvvf-s6ywy-t2ldf-6x3tv-ekdjg-f6ww5-oczmh-k6r54-2ae    16
# ehizo-zv4le-hkzuy-gqyvw-6enab-mazoj-p57ci-kesea-4ufju-d3jv4-oae    16
# r5i76-zvt2k-ssuo3-on5tn-gl7fr-vvx3g-mits2-inmhe-ohouc-ebdik-3qe    16
# ul75e-6e3ls-pno2p-y3plc-cd2gq-dfnw4-56woc-s45vm-ipu6u-lotli-uae    18
# Name: node_id, Length: 75, dtype: int64

# %% [markdown]
# # Sanity check: give records for which more than 100% of rounds were non-productive (should be empty always)

# %%
df[df["node_failed_rounds_percent"] > 100]
# Out:
# Empty DataFrame
# Columns: [node_id, num_blocks_total, num_block_failures_total, num_blocks_diff, num_block_failures_diff, subnet_id, timestamp_nanos, date, node_failed_rounds_percent]
# Index: []

# %% [markdown]
# # Plots

# %% [markdown]
# ## Plot all records in which nodes were unproductive for more than 10% of time

# %%
plt.figure()
df10 = df[df["node_failed_rounds_percent"] > 10]
ax = df10.plot(kind="scatter", x='date', y='node_failed_rounds_percent', ylabel="Percentage of failed block rounds for the node", title="Reliability of unreliable nodes over time", figsize=(12, 6), s=1)
plt.xticks(df10["date"], rotation=90)
plt.show()

# %% [markdown]
# ## Plot percentage of failed block rounds for a particular node id

# %%
from ipywidgets import interact, widgets

node_ids_widget = widgets.Combobox(
    placeholder='Type a node id',
    options=list(df["node_id"].unique()),
    description='Combobox:',
    ensure_option=True,
    disabled=False
)

# display(node_ids_widget)

@interact(node_id = node_ids_widget)
def plot_node_id(node_id):
    if node_id:
        df_node = df[df["node_id"] == node_id]
        df_node.plot(kind="scatter", x='date', y='node_failed_rounds_percent', ylabel="Percentage of blocks", title="Percentage of blocks for which node failed to propose a block", figsize=(12, 6), s=1)
        plt.xticks(df_node["date"], rotation=90)
        plt.show()
# Out:
# interactive(children=(Combobox(value='', description='Combobox:', ensure_option=True, options=('3ppfv-vqufk-yr…

# %%
df_node = df[df["node_id"] == "r5i76-zvt2k-ssuo3-on5tn-gl7fr-vvx3g-mits2-inmhe-ohouc-ebdik-3qe"]
df_node.plot(kind="scatter", x='date', y='node_failed_rounds_percent', ylabel="Percentage of blocks", title="Percentage of blocks for which node failed to propose a block", figsize=(12, 6), s=1)
plt.xticks(df_node["date"], rotation=90)
plt.show()
